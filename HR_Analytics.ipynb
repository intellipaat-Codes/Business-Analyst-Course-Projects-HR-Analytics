# %%
# HR case study
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp

# %%
empds= pd.read_csv("employees.csv")
empds.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
empds.shape
# Out:
# (14999, 10)

# %%
empds.describe()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# count       14999.000000    14999.000000      14999.000000     14999.000000
# mean            0.612834        0.716102          3.803054       201.050337
# std             0.248631        0.171169          1.232592        49.943099
# min             0.090000        0.360000          2.000000        96.000000
# 25%             0.440000        0.560000          3.000000       156.000000
# 50%             0.640000        0.720000          4.000000       200.000000
# 75%             0.820000        0.870000          5.000000       245.000000
# max             1.000000        1.000000          7.000000       310.000000
#
#        timeSpent.company  workAccident          left  promotionInLast5years
# count       14999.000000  14999.000000  14999.000000           14999.000000
# mean            3.498233      0.144610      0.238083               0.021268
# ...

# %%
empds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# data preprocessing

# isnull() or isna() both does same function

# identify the missing values
empds.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
#Mean,Median filling of the missing  values
# Dropping all the records of missing values
empds.dropna()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %% [markdown]
# # check duplicate recods and simply have the unique records into dataset
#
# empds.duplicated(subset=None, keep='first')

# %%
empds[empds.duplicated(subset=None, keep='first')]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
empds.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995    False
# 14996    False
# 14997    False
# 14998    False
# Length: 14999, dtype: bool

# %%
#drop duplciates
empds.drop_duplicates(keep='first')
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
#correlation
empds.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.105021         -0.142970
# lastEvaluation                  0.105021        1.000000          0.349333
# numberOfProjects               -0.142970        0.349333          1.000000
# avgMonthlyHours                -0.020048        0.339742          0.417211
# timeSpent.company              -0.100866        0.131591          0.196786
# workAccident                    0.058697       -0.007104         -0.004741
# left                           -0.388375        0.006567          0.023787
# promotionInLast5years           0.025605       -0.008684         -0.006064
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.020048          -0.100866      0.058697
# lastEvaluation                0.339742           0.131591     -0.007104
# numberOfProjects              0.417211           0.196786     -0.004741
# ...

# %%
# Data visualization segment ; analysing different features
features = ['dept','salary','numberOfProjects','timeSpent.company','workAccident']
features
# Out:
# ['dept', 'salary', 'numberOfProjects', 'timeSpent.company', 'workAccident']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig =plt.subplots(figsize=(10,15))

# p is index and q is the data column from dataset :features
for p,q in enumerate(features):
    plt.subplot(4,2,p+1)
    plt.subplots_adjust(hspace=1.0)
    sns.countplot(x=q,data=empds,hue='left')
    plt.xticks(rotation =90)

# %%
# understanding 

# attrition rate :number of employees left / number of total employees

# years of experience 3- 6 yrs ; attrition rate more

# promotion ---> significant role 

# salary ---> Low ,Medium , attrition rate high

# conclusion

# pormotion --> if no promotion in 5 years,likely to quit

# Time with company -->After 3 years , there is more chances to quit ;crucial time for employee to churning out

# No of engagement : if oppurtunities are less or if the employee is overburnden with more projects, more chances to quit.

# salary ---> Low ,Medium , more chances to quit ;incentive based salary policies to be introduced

# Drill report :Dash(web hosting),ployly

# Power BI,Tableau
